# %% [markdown]
# <a href="https://colab.research.google.com/github/NSP2023/ML-Learning-and-tasks/blob/main/Lab1_1B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.random.randint(1,201,30)
print(a)
print(np.mean(a))
print(np.std(a))
# Out:
# [102  81 160  47 152 156  16   4  14  81 197  87  64  95 115  40  46  92
#  161 110  58  59 137 110 113 142  25  96 129 117]
# 93.53333333333333
# 48.48761583011572

# %%
a=['noshin','syara','promitee']
print(a)

def isThere(name):
  if name in a:
    print("It is available")
  else:
    print("It was not avaiable")

isThere('promitee')
# Out:
# ['noshin', 'syara', 'promitee']
# It is available

# %%
import numpy as np
import matplotlib.pyplot as plt



x=np.linspace(0,100,200)
y=np.exp(x)

plt.plot(x,y)
plt.show()
